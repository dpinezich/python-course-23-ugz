# %% [markdown]
# # Seaborn
# * Seaborn ist eine Python-Datenvisualisierungsbibliothek, die auf matplotlib basiert.
# * Sie bietet eine High-Level-Schnittstelle zum Zeichnen attraktiver und informativer statistischer Grafiken
# * Seaborn funktioniert wunderbar mit *Pandas*.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
sns.__version__
# Out:
# '0.12.2'

# %%
# Eventually needed security:
# console: jupyter trust material/seaborn.ipynb
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Überblick
# Um einen ersten Eindruck davon zu erhalten, wie einfach seaborn funktioniert, sehen Sie sich den folgenden Code an:

# %%
df_obj1 = pd.DataFrame({"x": np.random.randn(500),
                   "y": np.random.randn(500)})

df_obj2 = pd.DataFrame({"x": np.random.randn(500),
                   "y": np.random.randint(0, 100, 500)})

df_obj2.describe()
# Out:
#                 x           y
# count  500.000000  500.000000
# mean    -0.007860   49.800000
# std      1.028053   28.769835
# min     -3.246493    0.000000
# 25%     -0.637521   26.000000
# 50%     -0.011651   52.000000
# 75%      0.743220   74.000000
# max      3.055253   99.000000

# %% [markdown]
# #### Default

# %%
sns.jointplot(x="x", y="y", data=df_obj2)

# %% [markdown]
# #### Hex

# %%
sns.jointplot(x="x", y="y", data=df_obj2, kind="hex")

# %% [markdown]
# #### Kde

# %%
sns.jointplot(x="x", y="y", data=df_obj1, kind="kde")

# %% [markdown]
# #### Pairplot

# %%
dataset = sns.load_dataset("tips")
sns.pairplot(dataset)
# Out:
# /Users/davidpinezich/Development/teaching/python-course-23-ugz/venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Überblick - erweitert
# Auch die DataFrames sind bereits bekannt, denn es sind die gleichen wie man von Pandas kennt.
# Mit einigen wenigen Zeilen Code (und zufälligen Punkten) haben wir 3 Plots und einen Paar-Plot erstellt.

# %% [markdown]
# ## Overview - Mehr Diagrammarten
# Nun schauen wir uns verschiedene Diagramme an.

# %%
exercise = sns.load_dataset('exercise')

#sns.stripplot(x="diet", y="pulse", data=exercise)
#sns.swarmplot(x="diet", y="pulse", data=exercise, hue='kind')
#sns.boxplot(x="diet", y="pulse", data=exercise)
#sns.boxplot(x="diet", y="pulse", data=exercise, hue='kind')
sns.violinplot(x="diet", y="pulse", data=exercise, hue='kind')
#sns.barplot(x="diet", y="pulse", data=exercise, hue='kind')
#sns.pointplot(x="diet", y="pulse", data=exercise, hue='kind');

plt.show()

# %% [markdown]
# ## Überblick - Noch mehr Datensätze
# Als nächstes schauen wir uns noch mehr Datensätze an die Seaborn zu bieten hat.

# %%
titanic = sns.load_dataset('titanic')
#planets = sns.load_dataset('planets')
#flights = sns.load_dataset('flights')
#iris = sns.load_dataset('iris')

titanic.head(30)

# see them all? print(sns.get_datasets_names())
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic = sns.load_dataset('titanic')
#planets = sns.load_dataset('planets')
#flights = sns.load_dataset('flights')
#iris = sns.load_dataset('iris')

titanic.head(30)

# see them all? print(sns.get_datasets_names())
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %% [markdown]
# # Car Crashes
# Lasst uns einen weiteren Rundgang durch Seaborn machen, dieses Mal mit mehr Details.
# Dazu verwenden wir den integrierten Datensatz für Autounfälle.

# %%
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ## df.head
# df.head() kennen wir bereits, es eignet sich wunderbar um sich einen ersten Überblick zu verschaffen.
#
# ## Styling & Themes
# Wir verwenden Visualisierungen, um Erkenntnisse aus einer riesigen Datenmenge zu gewinnen oder unsere Erkenntnisse Interessengruppen zu präsentieren, und eine ansprechende Gestaltung dieser Visualisierungen kann sicherlich bei beidem helfen.
#
# Menschen konzentrieren sich eher auf schöne und attraktive Visualisierungen als auf langweilige Diagramme, daher kann das Styling als eine wichtige Komponente der Datenvisualisierung angesehen werden.
#
# Die Matplotlib-Bibliothek ist in hohem Masse anpassbar, aber es kann schwierig sein, die richtigen Einstellungen zu finden. Hier bietet Seaborn eine Highlevel-Schnittstelle an.
#
# ## Example

# %%
from matplotlib import pyplot as plt_norm
plt_norm.scatter(df.speeding,df.alcohol)
plt_norm.show()

# %% [markdown]
# ## Ein anderes Beispiel

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df.speeding,df.alcohol)
sns.set_style("darkgrid")
plt.show()

# %% [markdown]
# Die beiden obigen Abbildungen zeigen den Unterschied zwischen den Standarddiagrammen von Matplotlib und Seaborn. Die Darstellung der Daten ist die Gleiche, aber es gibt einen kleinen Unterschied in der Gestaltung der Diagramme.
#
# Seaborn unterstützt verschiedene Themen, die das Styling der Plots sehr einfach machen und viel Zeit sparen können. Mit der set_style()-Funktion von Seaborn können wir jedes der in der Seaborn-Bibliothek verfügbaren Themen einstellen. Hier sind ein paar der beliebtesten Themen:
# * Darkgrid
# * Whitegrid
# * Dark
# * White
# * Ticks

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df.speeding,df.alcohol)
sns.set_style("dark")
plt.show()

# %% [markdown]
# Seaborn ermöglicht es uns auch, einzelne Elemente unserer Diagramme zu steuern,  so können wir die Skalierung dieser Elemente oder der Darstellung mit der Funktion set_context() beeinflussen. Wir haben vier voreingestellte Vorlagen für Kontexte, basierend auf der relativen Größe, die Kontexte sind wie folgt benannt:
#
# * Paper
# * Notebook
# * Talk
# * Poster

# %% [markdown]
# ## Reset
#
# Es kann vorkommen, dass Sie Ihre Standardeinstellungen zurücksetzen müssen, weil Ihr Diagramm bereits gestaltet wurde, die Gestaltung für das nächste Diagramm aber anders sein soll.

# %%
import matplotlib as mpl
import importlib
importlib.reload(mpl); importlib.reload(plt); importlib.reload(sns)
# Out:
# <module 'seaborn' from '/Users/davidpinezich/Development/teaching/python-course-23-ugz/venv/lib/python3.11/site-packages/seaborn/__init__.py'>

# %% [markdown]
# ## Color Palette
# Werfen wir nun einen Blick auf die verschiedenen Farbpaletten, die Seaborn anbietet

# %%
sns.palplot(sns.color_palette("GnBu", 10))
sns.palplot(sns.color_palette("PiYG", 10))
sns.palplot(sns.color_palette("deep", 10))

# %% [markdown]
# ### Lasst uns ein paar bunte Parzellen haben

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", palette='colorblind')

# %% [markdown]
# #### Histogram

# %%
import seaborn as sns
from matplotlib import pyplot as plt
df = sns.load_dataset('iris')
sns.displot(df['petal_length'],kde = False)

# %% [markdown]
# #### Barplot+

# %%
import matplotlib.pyplot as plt
import seaborn as sns
titanic = sns.load_dataset('titanic')
# create plot
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = titanic,
            palette = 'PuRd',
            order = ['male', 'female'],
            capsize = 0.05,
            saturation = 8,
            errcolor = 'gray', errwidth = 2,
            ci = 'sd'
            )
plt.legend()
plt.show()

# %% [markdown]
# #### Countplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('paper')

# load dataset
titanic = sns.load_dataset('titanic')
# create plot
sns.countplot(x = 'class', hue = 'who', data = titanic, palette = 'magma')
plt.title('Survivors')
plt.show()

# %% [markdown]
# #### Pointplot

# %%
# importing required packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")
sns.pointplot(x="day", y="tip", data=data)
plt.show()

# %% [markdown]
# #### Regplot

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# #### Schlussbeispiel
# Das letzte Beispiel ist eine Heatmap für Flüge:

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
print(flights)
sns.heatmap(flights,linewidths=.5,cmap="YlGnBu")
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# #### Schlussbeispiel v2
# Und nun zurück zu "car crashes", diesmal mit einem schönen Histogramm:

# %%
import seaborn as sns
car_crashes = sns.load_dataset("car_crashes")
corr=car_crashes.corr()
print(corr)
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000
# <AxesSubplot:>
